# %% [markdown]
# <a href="https://colab.research.google.com/github/Fathanhelmi/PMML/blob/main/Tugas_1_PMML_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
import gspread
from google.colab import auth
from google.auth import default

# %%
url = 'https://books.toscrape.com/'
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
pages = []
i=1
while True:
  url_page = f"{url}catalogue/page-{i}.html"
  page_response = requests.get(url_page)
  if page_response.status_code == 200:
    pages.append(url_page)
    print(url_page)
    i+=1
  else:
    break
print(f"Found {len(pages)} pages.")
# Out:
# https://books.toscrape.com/catalogue/page-1.html
# https://books.toscrape.com/catalogue/page-2.html
# https://books.toscrape.com/catalogue/page-3.html
# https://books.toscrape.com/catalogue/page-4.html
# https://books.toscrape.com/catalogue/page-5.html
# https://books.toscrape.com/catalogue/page-6.html
# https://books.toscrape.com/catalogue/page-7.html
# https://books.toscrape.com/catalogue/page-8.html
# https://books.toscrape.com/catalogue/page-9.html
# https://books.toscrape.com/catalogue/page-10.html
# https://books.toscrape.com/catalogue/page-11.html
# https://books.toscrape.com/catalogue/page-12.html
# https://books.toscrape.com/catalogue/page-13.html
# https://books.toscrape.com/catalogue/page-14.html
# https://books.toscrape.com/catalogue/page-15.html
# https://books.toscrape.com/catalogue/page-16.html
# https://books.toscrape.com/catalogue/page-17.html
# https://books.toscrape.com/catalogue/page-18.html
# https://books.toscrape.com/catalogue/page-19.html
# https://books.toscrape.com/catalogue/page-20.html
# https://books.toscrape.com/catalogue/page-21.html
# https://books.toscrape.com/catalogue/page-22.html
# https://books.toscrape.com/catalogue/page-23.html
# https://books.toscrape.com/catalogue/page-24.html
# https://books.toscrape.com/catalogue/page-25.html
# https://books.toscrape.com/catalogue/page-26.html
# https://books.toscrape.com/catalogue/page-27.html
# https://books.toscrape.com/catalogue/page-28.html
# https://books.toscrape.com/catalogue/page-29.html
# https://books.toscrape.com/catalogue/page-30.html
# https://books.toscrape.com/catalogue/page-31.html
# https://books.toscrape.com/catalogue/page-32.html
# https://books.toscrape.com/catalogue/page-33.html
# https://books.toscrape.com/catalogue/page-34.html
# https://books.toscrape.com/catalogue/page-35.html
# https://books.toscrape.com/catalogue/page-36.html
# https://books.toscrape.com/catalogue/page-37.html
# https://books.toscrape.com/catalogue/page-38.html
# https://books.toscrape.com/catalogue/page-39.html
# https://books.toscrape.com/catalogue/page-40.html
# https://books.toscrape.com/catalogue/page-41.html
# https://books.toscrape.com/catalogue/page-42.html
# https://books.toscrape.com/catalogue/page-43.html
# https://books.toscrape.com/catalogue/page-44.html
# https://books.toscrape.com/catalogue/page-45.html
# https://books.toscrape.com/catalogue/page-46.html
# https://books.toscrape.com/catalogue/page-47.html
# https://books.toscrape.com/catalogue/page-48.html
# https://books.toscrape.com/catalogue/page-49.html
# https://books.toscrape.com/catalogue/page-50.html
# Found 50 pages.

# %%
page1 = 'https://books.toscrape.com/catalogue/page-1.html'
page_response=requests.get(page1)
page_soup = BeautifulSoup(page_response.content, 'html.parser')
books = [url + 'catalogue/' + link.get('href')for link in page_soup.select('h3 a')]
books
# Out:
# ['https://books.toscrape.com/catalogue/a-light-in-the-attic_1000/index.html',
#  'https://books.toscrape.com/catalogue/tipping-the-velvet_999/index.html',
#  'https://books.toscrape.com/catalogue/soumission_998/index.html',
#  'https://books.toscrape.com/catalogue/sharp-objects_997/index.html',
#  'https://books.toscrape.com/catalogue/sapiens-a-brief-history-of-humankind_996/index.html',
#  'https://books.toscrape.com/catalogue/the-requiem-red_995/index.html',
#  'https://books.toscrape.com/catalogue/the-dirty-little-secrets-of-getting-your-dream-job_994/index.html',
#  'https://books.toscrape.com/catalogue/the-coming-woman-a-novel-based-on-the-life-of-the-infamous-feminist-victoria-woodhull_993/index.html',
#  'https://books.toscrape.com/catalogue/the-boys-in-the-boat-nine-americans-and-their-epic-quest-for-gold-at-the-1936-berlin-olympics_992/index.html',
#  'https://books.toscrape.com/catalogue/the-black-maria_991/index.html',
#  'https://books.toscrape.com/catalogue/starving-hearts-triangular-trade-trilogy-1_990/index.html',
#  'https://books.toscrape.com/catalogue/shakespeares-sonnets_989/index.html',
#  'https://books.toscrape.com/catalogue/set-me-free_988/index.html',
#  'https://books.toscrape.com/catalogue/scott-pilgrims-precious-little-life-scott-pilgrim-1_987/index.html',
#  'https://books.toscrape.com/catalogue/rip-it-up-and-start-again_986/index.html',
#  'https://books.toscrape.com/catalogue/our-band-could-be-your-life-scenes-from-the-american-indie-underground-1981-1991_985/index.html',
#  'https://books.toscrape.com/catalogue/olio_984/index.html',
#  'https://books.toscrape.com/catalogue/mesaerion-the-best-science-fiction-stories-1800-1849_983/index.html',
#  'https://books.toscrape.com/catalogue/libertarianism-for-beginners_982/index.html',
#  'https://books.toscrape.com/catalogue/its-only-the-himalayas_981/index.html']

# %%
book_urls = []
for page in pages:
  page_response=requests.get(page)
  page_soup = BeautifulSoup(page_response.content, 'html.parser')
  book_links = [url + 'catalogue/'+ link.get('href')for link in page_soup.select('h3 a')]
  book_urls.extend(book_links)
  print(f"{page} : {len(book_links)}books.")

print(f"Found {len(book_urls)} books.")
# Out:
# https://books.toscrape.com/catalogue/page-1.html : 20books.
# https://books.toscrape.com/catalogue/page-2.html : 20books.
# https://books.toscrape.com/catalogue/page-3.html : 20books.
# https://books.toscrape.com/catalogue/page-4.html : 20books.
# https://books.toscrape.com/catalogue/page-5.html : 20books.
# https://books.toscrape.com/catalogue/page-6.html : 20books.
# https://books.toscrape.com/catalogue/page-7.html : 20books.
# https://books.toscrape.com/catalogue/page-8.html : 20books.
# https://books.toscrape.com/catalogue/page-9.html : 20books.
# https://books.toscrape.com/catalogue/page-10.html : 20books.
# https://books.toscrape.com/catalogue/page-11.html : 20books.
# https://books.toscrape.com/catalogue/page-12.html : 20books.
# https://books.toscrape.com/catalogue/page-13.html : 20books.
# https://books.toscrape.com/catalogue/page-14.html : 20books.
# https://books.toscrape.com/catalogue/page-15.html : 20books.
# https://books.toscrape.com/catalogue/page-16.html : 20books.
# https://books.toscrape.com/catalogue/page-17.html : 20books.
# https://books.toscrape.com/catalogue/page-18.html : 20books.
# https://books.toscrape.com/catalogue/page-19.html : 20books.
# https://books.toscrape.com/catalogue/page-20.html : 20books.
# https://books.toscrape.com/catalogue/page-21.html : 20books.
# https://books.toscrape.com/catalogue/page-22.html : 20books.
# https://books.toscrape.com/catalogue/page-23.html : 20books.
# https://books.toscrape.com/catalogue/page-24.html : 20books.
# https://books.toscrape.com/catalogue/page-25.html : 20books.
# https://books.toscrape.com/catalogue/page-26.html : 20books.
# https://books.toscrape.com/catalogue/page-27.html : 20books.
# https://books.toscrape.com/catalogue/page-28.html : 20books.
# https://books.toscrape.com/catalogue/page-29.html : 20books.
# https://books.toscrape.com/catalogue/page-30.html : 20books.
# https://books.toscrape.com/catalogue/page-31.html : 20books.
# https://books.toscrape.com/catalogue/page-32.html : 20books.
# https://books.toscrape.com/catalogue/page-33.html : 20books.
# https://books.toscrape.com/catalogue/page-34.html : 20books.
# https://books.toscrape.com/catalogue/page-35.html : 20books.
# https://books.toscrape.com/catalogue/page-36.html : 20books.
# https://books.toscrape.com/catalogue/page-37.html : 20books.
# https://books.toscrape.com/catalogue/page-38.html : 20books.
# https://books.toscrape.com/catalogue/page-39.html : 20books.
# https://books.toscrape.com/catalogue/page-40.html : 20books.
# https://books.toscrape.com/catalogue/page-41.html : 20books.
# https://books.toscrape.com/catalogue/page-42.html : 20books.
# https://books.toscrape.com/catalogue/page-43.html : 20books.
# https://books.toscrape.com/catalogue/page-44.html : 20books.
# https://books.toscrape.com/catalogue/page-45.html : 20books.
# https://books.toscrape.com/catalogue/page-46.html : 20books.
# https://books.toscrape.com/catalogue/page-47.html : 20books.
# https://books.toscrape.com/catalogue/page-48.html : 20books.
# https://books.toscrape.com/catalogue/page-49.html : 20books.
# https://books.toscrape.com/catalogue/page-50.html : 20books.
# Found 1000 books.

# %%
from itertools import product
book_url_1 = book_urls[0]
book_response = requests.get(book_url_1)
book_soup = BeautifulSoup(book_response.content, 'html.parser')

category = book_soup.select_one('.breadcrumb li:nth-child(3) a').get_text()
print(category)

title = book_soup.select_one('h1').get_text()
print(title)

rating = book_soup.select_one('p.star-rating')['class'][1]
print(rating)

description_element = book_soup.select_one('#product_description ~ p')
description = description_element.get_text() if description_element else 'No description available'
print(description)

cover = url + book_soup.select_one('#product_gallery img')['src'].replace('../','')
print(cover)

product_info = book_soup.select_one('table.table-striped tr')

code = product_info[0].select_one('td').get_text()
print(code)

price_incl_tax = float(product_info[2].select_one('td').get_text().replace('£', ''))
# Out:
# Poetry
# A Light in the Attic
# Three
# It's hard to imagine a world without A Light in the Attic. This now-classic collection of poetry and drawings from Shel Silverstein celebrates its 20th anniversary with this special edition. Silverstein's humorous and creative verse can amuse the dowdiest of readers. Lemon-faced adults and fidgety kids sit still and read these rhythmic words and laugh and smile and love th It's hard to imagine a world without A Light in the Attic. This now-classic collection of poetry and drawings from Shel Silverstein celebrates its 20th anniversary with this special edition. Silverstein's humorous and creative verse can amuse the dowdiest of readers. Lemon-faced adults and fidgety kids sit still and read these rhythmic words and laugh and smile and love that Silverstein. Need proof of his genius? RockabyeRockabye baby, in the treetopDon't you know a treetopIs no safe place to rock?And who put you up there,And your cradle, too?Baby, I think someone down here'sGot it in for you. Shel, you never sounded so good. ...more
# https://books.toscrape.com/media/cache/fe/72/fe72f0532301ec28892ae79a629a293c.jpg

# %%
#!/usr/bin/env python3
"""
scrape_books_toscrape.py
Scrapes https://books.toscrape.com/ to produce a dataframe of ~1000 books with requested fields.

Usage:
    python scrape_books_toscrape.py

Outputs:
    - books.csv (CSV)
    - books.parquet (optional, faster to load)
"""

import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import re
import time
import random
import pandas as pd
from typing import List, Dict

BASE_URL = "https://books.toscrape.com/"

HEADERS = {
    "User-Agent": "Mozilla/5.0 (compatible; Scraper/1.0; +https://example.com/bot)"
}

# map rating word in class to number
RATING_MAP = {
    "One": 1,
    "Two": 2,
    "Three": 3,
    "Four": 4,
    "Five": 5
}


def get_soup(url: str, session: requests.Session) -> BeautifulSoup:
    r = session.get(url, headers=HEADERS, timeout=20)
    r.raise_for_status()
    return BeautifulSoup(r.text, "html.parser")


def parse_book_page(book_url: str, session: requests.Session) -> Dict:
    """Parse one product page and return dict with required fields."""
    soup = get_soup(book_url, session)

    # TITLE
    title_tag = soup.find("h1")
    title = title_tag.get_text(strip=True) if title_tag else ""

    # CATEGORY: breadcrumb last li (active)
    category = ""
    breadcrumb = soup.select_one("ul.breadcrumb")
    if breadcrumb:
        # last li with class 'active' usually holds category or product name (site uses category at 3rd pos)
        # On product page the breadcrumb structure is Home > Books > Category > Title
        lis = breadcrumb.find_all("li")
        if len(lis) >= 3:
            # Category is the 3rd li (index 2) normally
            cat_li = lis[-2]  # second-to-last is category
            category = cat_li.get_text(strip=True)

    # DESCRIPTION: product_description heading then next <p>
    description = ""
    prod_desc_h = soup.find("div", id="product_description")
    if prod_desc_h:
        desc_p = prod_desc_h.find_next_sibling("p")
        if desc_p:
            description = desc_p.get_text(strip=True)

    # COVER IMAGE
    cover_img = ""
    img_tag = soup.select_one("div.item.active img") or soup.select_one("div.carousel-inner img") or soup.select_one("div.product_gallery img")
    if not img_tag:
        img_tag = soup.select_one("div.thumbnail img")  # fallback
    if img_tag and img_tag.get("src"):
        cover_src = img_tag["src"]
        cover_img = urljoin(book_url, cover_src)

    # PRODUCT TABLE: UPC, prices, tax, availability, number of reviews
    product_info = {}
    table = soup.find("table", class_="table table-striped")
    if table:
        for row in table.find_all("tr"):
            th = row.find("th")
            td = row.find("td")
            if not th or not td:
                continue
            key = th.get_text(strip=True)
            val = td.get_text(strip=True)
            product_info[key] = val

    # fields from product_info
    code = product_info.get("UPC", "")
    price_excl = product_info.get("Price (excl. tax)", "")
    price_incl = product_info.get("Price (incl. tax)", "")
    tax = product_info.get("Tax", "")
    number_of_reviews = product_info.get("Number of reviews", "")
    # normalize number_of_reviews to int if possible
    try:
        number_of_reviews = int(number_of_reviews)
    except:
        number_of_reviews = None

    # STOCK STATUS and number available
    availability_text = product_info.get("Availability", "") or ""
    stock_status = availability_text
    number_in_stock = None
    # example availability: "In stock (22 available)"
    m = re.search(r"\((\d+)\s+available\)", availability_text)
    if m:
        number_in_stock = int(m.group(1))
    else:
        # sometimes only "In stock"
        if "In stock" in availability_text:
            number_in_stock = None  # unspecified
        else:
            number_in_stock = 0

    # RATING: look for <p class="star-rating Three">
    rating_val = None
    rating_p = soup.find("p", class_=re.compile(r"star-rating"))
    if rating_p:
        classes = rating_p.get("class", [])
        # classes contain 'star-rating' and the word e.g. 'Three'
        for c in classes:
            if c in RATING_MAP:
                rating_val = RATING_MAP[c]
                break

    result = {
        "category": category,
        "code": code,
        "cover": cover_img,
        "title": title,
        "rating": rating_val,
        "price (excl. tax)": price_excl,
        "price (incl. tax)": price_incl,
        "tax": tax,
        "stock status": stock_status,
        "number of stock available": number_in_stock,
        "description": description,
        "number of reviews": number_of_reviews,
        "product_page_url": book_url
    }

    return result


def get_book_links_from_listing(page_soup: BeautifulSoup, base_page_url: str) -> List[str]:
    """Extract absolute product page URLs from a listing page soup."""
    links = []
    # product_pod -> h3 -> a[href]
    for article in page_soup.select("article.product_pod"):
        a = article.find("h3").find("a")
        href = a.get("href")
        if href:
            full = urljoin(base_page_url, href)
            # site sometimes uses relative paths with '../', urljoin handles it
            links.append(full)
    return links


def find_next_page(soup: BeautifulSoup, current_page_url: str) -> str:
    """Return absolute URL of 'next' page if exists else None."""
    li = soup.find("li", class_="next")
    if li and li.find("a"):
        href = li.find("a")["href"]
        return urljoin(current_page_url, href)
    return None


def scrape_all_books(max_books: int = 1100, delay_range=(0.2, 0.6)) -> pd.DataFrame:
    """Scrape until we collect max_books or no more pages. Default max slightly >1000."""
    session = requests.Session()
    results = []
    visited_books = set()

    next_page = BASE_URL  # starts at homepage
    page_count = 0

    while next_page and len(results) < max_books:
        page_count += 1
        print(f"[page {page_count}] fetching listing: {next_page}")
        try:
            soup = get_soup(next_page, session)
        except Exception as e:
            print(f"Failed to fetch listing page {next_page}: {e}")
            break

        book_links = get_book_links_from_listing(soup, next_page)
        print(f"  -> found {len(book_links)} product links on page")

        for link in book_links:
            # Some listing links are to the same product across pages; skip duplicates
            if link in visited_books:
                continue
            visited_books.add(link)

            # polite delay
            time.sleep(random.uniform(*delay_range))

            try:
                book_data = parse_book_page(link, session)
            except Exception as e:
                print(f"  ! Failed parse {link}: {e}")
                continue

            results.append(book_data)
            print(f"  + scraped: {book_data['title'][:60]}")

            # stop early if reached target
            if len(results) >= max_books:
                break

        # find next listing page
        next_page = find_next_page(soup, next_page)

    df = pd.DataFrame(results)
    # Reorder columns to match requested variables (plus product_page_url)
    cols = [
        "category", "code", "cover", "title", "rating",
        "price (excl. tax)", "price (incl. tax)", "tax",
        "stock status", "number of stock available", "description",
        "number of reviews", "product_page_url"
    ]
    # keep only columns that exist
    cols = [c for c in cols if c in df.columns]
    df = df[cols]
    return df


def main():
    # target 1000 books (the site has 1000 books)
    print("Starting scrape of books.toscrape.com ...")
    df = scrape_all_books(max_books=1000)

    print(f"Scraped {len(df)} books. Saving to CSV...")
    df.to_csv("books.csv", index=False)
    try:
        df.to_parquet("books.parquet", index=False)
    except Exception:
        pass

    print("Saved to books.csv (and books.parquet if pyarrow installed).")
    print("Columns:", df.columns.tolist())
    # show small sample
    print(df.head(3).to_dict(orient="records"))


if __name__ == "__main__":
    main()
# Out:
# Starting scrape of books.toscrape.com ...
# [page 1] fetching listing: https://books.toscrape.com/
#   -> found 20 product links on page
#   + scraped: A Light in the Attic
#   + scraped: Tipping the Velvet
#   + scraped: Soumission
#   + scraped: Sharp Objects
#   + scraped: Sapiens: A Brief History of Humankind
#   + scraped: The Requiem Red
#   + scraped: The Dirty Little Secrets of Getting Your Dream Job
#   + scraped: The Coming Woman: A Novel Based on the Life of the Infamous
#   + scraped: The Boys in the Boat: Nine Americans and Their Epic Quest fo
#   + scraped: The Black Maria
#   + scraped: Starving Hearts (Triangular Trade Trilogy, #1)
#   + scraped: Shakespeare's Sonnets
#   + scraped: Set Me Free
#   + scraped: Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)
#   + scraped: Rip it Up and Start Again
#   + scraped: Our Band Could Be Your Life: Scenes from the American Indie
#   + scraped: Olio
#   + scraped: Mesaerion: The Best Science Fiction Stories 1800-1849
#   + scraped: Libertarianism for Beginners
#   + scraped: It's Only the Himalayas
# [page 2] fetching listing: https://books.toscrape.com/catalogue/page-2.html
#   -> found 20 product links on page
#   + scraped: In Her Wake
#   + scraped: How Music Works
#   + scraped: Foolproof Preserving: A Guide to Small Batch Jams, Jellies,
#   + scraped: Chase Me (Paris Nights #2)
#   + scraped: Black Dust
#   + scraped: Birdsong: A Story in Pictures
#   + scraped: America's Cradle of Quarterbacks: Western Pennsylvania's Foo
#   + scraped: Aladdin and His Wonderful Lamp
#   + scraped: Worlds Elsewhere: Journeys Around Shakespeareâs Globe
#   + scraped: Wall and Piece
#   + scraped: The Four Agreements: A Practical Guide to Personal Freedom
#   + scraped: The Five Love Languages: How to Express Heartfelt Commitment
#   + scraped: The Elephant Tree
#   + scraped: The Bear and the Piano
#   + scraped: Sophie's World
#   + scraped: Penny Maybe
#   + scraped: Maude (1883-1993):She Grew Up with the country
#   + scraped: In a Dark, Dark Wood
#   + scraped: Behind Closed Doors
#   + scraped: You can't bury them all: Poems
# [page 3] fetching listing: https://books.toscrape.com/catalogue/page-3.html
#   -> found 20 product links on page
#   + scraped: Slow States of Collapse: Poems
#   + scraped: Reasons to Stay Alive
#   + scraped: Private Paris (Private #10)
#   + scraped: #HigherSelfie: Wake Up Your Life. Free Your Soul. Find Your
#   + scraped: Without Borders (Wanderlove #1)
#   + scraped: When We Collided
#   + scraped: We Love You, Charlie Freeman
#   + scraped: Untitled Collection: Sabbath Poems 2014
#   + scraped: Unseen City: The Majesty of Pigeons, the Discreet Charm of S
#   + scraped: Unicorn Tracks
#   + scraped: Unbound: How Eight Technologies Made Us Human, Transformed S
#   + scraped: Tsubasa: WoRLD CHRoNiCLE 2 (Tsubasa WoRLD CHRoNiCLE #2)
#   + scraped: Throwing Rocks at the Google Bus: How Growth Became the Enem
#   + scraped: This One Summer
#   + scraped: Thirst
#   + scraped: The Torch Is Passed: A Harding Family Story
#   + scraped: The Secret of Dreadwillow Carse
#   + scraped: The Pioneer Woman Cooks: Dinnertime: Comfort Classics, Freez
#   + scraped: The Past Never Ends
#   + scraped: The Natural History of Us (The Fine Art of Pretending #2)
# [page 4] fetching listing: https://books.toscrape.com/catalogue/page-4.html
#   -> found 20 product links on page
#   + scraped: The Nameless City (The Nameless City #1)
#   + scraped: The Murder That Never Was (Forensic Instincts #5)
#   + scraped: The Most Perfect Thing: Inside (and Outside) a Bird's Egg
#   + scraped: The Mindfulness and Acceptance Workbook for Anxiety: A Guide
#   + scraped: The Life-Changing Magic of Tidying Up: The Japanese Art of D
#   + scraped: The Inefficiency Assassin: Time Management Tactics for Worki
#   + scraped: The Gutsy Girl: Escapades for Your Life of Epic Adventure
#   + scraped: The Electric Pencil: Drawings from Inside State Hospital No.
#   + scraped: The Death of Humanity: and the Case for Life
#   + scraped: The Bulletproof Diet: Lose up to a Pound a Day, Reclaim Ener
#   + scraped: The Art Forger
#   + scraped: The Age of Genius: The Seventeenth Century and the Birth of
#   + scraped: The Activist's Tao Te Ching: Ancient Advice for a Modern Rev
#   + scraped: Spark Joy: An Illustrated Master Class on the Art of Organiz
#   + scraped: Soul Reader
#   + scraped: Security
#   + scraped: Saga, Volume 6 (Saga (Collected Editions) #6)
#   + scraped: Saga, Volume 5 (Saga (Collected Editions) #5)
#   + scraped: Reskilling America: Learning to Labor in the Twenty-First Ce
#   + scraped: Rat Queens, Vol. 3: Demons (Rat Queens (Collected Editions)
# [page 5] fetching listing: https://books.toscrape.com/catalogue/page-5.html
#   -> found 20 product links on page
#   + scraped: Princess Jellyfish 2-in-1 Omnibus, Vol. 01 (Princess Jellyfi
#   + scraped: Princess Between Worlds (Wide-Awake Princess #5)
#   + scraped: Pop Gun War, Volume 1: Gift
#   + scraped: Political Suicide: Missteps, Peccadilloes, Bad Calls, Backro
#   + scraped: Patience
#   + scraped: Outcast, Vol. 1: A Darkness Surrounds Him (Outcast #1)
#   + scraped: orange: The Complete Collection 1 (orange: The Complete Coll
#   + scraped: Online Marketing for Busy Authors: A Step-By-Step Guide
#   + scraped: On a Midnight Clear
#   + scraped: Obsidian (Lux #1)
#   + scraped: My Paris Kitchen: Recipes and Stories
#   + scraped: Masks and Shadows
#   + scraped: Mama Tried: Traditional Italian Cooking for the Screwed, Cru
#   + scraped: Lumberjanes, Vol. 2: Friendship to the Max (Lumberjanes #5-8
#   + scraped: Lumberjanes, Vol. 1: Beware the Kitten Holy (Lumberjanes #1-
#   + scraped: Lumberjanes Vol. 3: A Terrible Plan (Lumberjanes #9-12)
#   + scraped: Layered: Baking, Building, and Styling Spectacular Cakes
#   + scraped: Judo: Seven Steps to Black Belt (an Introductory Guide for B
#   + scraped: Join
#   + scraped: In the Country We Love: My Family Divided
# [page 6] fetching listing: https://books.toscrape.com/catalogue/page-6.html
#   -> found 20 product links on page
#   + scraped: Immunity: How Elie Metchnikoff Changed the Course of Modern
#   + scraped: I Hate Fairyland, Vol. 1: Madly Ever After (I Hate Fairyland
#   + scraped: I am a Hero Omnibus Volume 1
#   + scraped: How to Be Miserable: 40 Strategies You Already Use
#   + scraped: Her Backup Boyfriend (The Sorensen Family #1)
#   + scraped: Giant Days, Vol. 2 (Giant Days #5-8)
#   + scraped: Forever and Forever: The Courtship of Henry Longfellow and F
#   + scraped: First and First (Five Boroughs #3)
#   + scraped: Fifty Shades Darker (Fifty Shades #2)
#   + scraped: Everydata: The Misinformation Hidden in the Little Data You
#   + scraped: Don't Be a Jerk: And Other Practical Advice from Dogen, Japa
#   + scraped: Danganronpa Volume 1
#   + scraped: Crown of Midnight (Throne of Glass #2)
#   + scraped: Codename Baboushka, Volume 1: The Conclave of Death
#   + scraped: Camp Midnight
#   + scraped: Call the Nurse: True Stories of a Country Nurse on a Scottis
#   + scraped: Burning
#   + scraped: Bossypants
#   + scraped: Bitch Planet, Vol. 1: Extraordinary Machine (Bitch Planet (C
#   + scraped: Avatar: The Last Airbender: Smoke and Shadow, Part 3 (Smoke
# [page 7] fetching listing: https://books.toscrape.com/catalogue/page-7.html
#   -> found 20 product links on page
#   + scraped: Algorithms to Live By: The Computer Science of Human Decisio
#   + scraped: A World of Flavor: Your Gluten Free Passport
#   + scraped: A Piece of Sky, a Grain of Rice: A Memoir in Four Meditation
#   + scraped: A Murder in Time
#   + scraped: A Flight of Arrows (The Pathfinders #2)
#   + scraped: A Fierce and Subtle Poison
#   + scraped: A Court of Thorns and Roses (A Court of Thorns and Roses #1)
#   + scraped: (Un)Qualified: How God Uses Broken People to Do Big Things
#   + scraped: You Are What You Love: The Spiritual Power of Habit
#   + scraped: William Shakespeare's Star Wars: Verily, A New Hope (William
#   + scraped: Tuesday Nights in 1980
#   + scraped: Tracing Numbers on a Train
#   + scraped: Throne of Glass (Throne of Glass #1)
#   + scraped: Thomas Jefferson and the Tripoli Pirates: The Forgotten War
#   + scraped: Thirteen Reasons Why
#   + scraped: The White Cat and the Monk: A Retelling of the Poem âPangu
#   + scraped: The Wedding Dress
#   + scraped: The Vacationers
#   + scraped: The Third Wave: An Entrepreneurâs Vision of the Future
#   + scraped: The Stranger
# [page 8] fetching listing: https://books.toscrape.com/catalogue/page-8.html
#   -> found 20 product links on page
#   + scraped: The Shadow Hero (The Shadow Hero)
#   + scraped: The Secret (The Secret #1)
#   + scraped: The Regional Office Is Under Attack!
#   + scraped: The Psychopath Test: A Journey Through the Madness Industry
#   + scraped: The Project
#   + scraped: The Power of Now: A Guide to Spiritual Enlightenment
#   + scraped: The Omnivore's Dilemma: A Natural History of Four Meals
#   + scraped: The Nerdy Nummies Cookbook: Sweet Treats for the Geek in All
#   + scraped: The Murder of Roger Ackroyd (Hercule Poirot #4)
#   + scraped: The Mistake (Off-Campus #2)
#   + scraped: The Matchmaker's Playbook (Wingmen Inc. #1)
#   + scraped: The Love and Lemons Cookbook: An Apple-to-Zucchini Celebrati
#   + scraped: The Long Shadow of Small Ghosts: Murder and Memory in an Ame
#   + scraped: The Kite Runner
#   + scraped: The House by the Lake
#   + scraped: The Glittering Court (The Glittering Court #1)
#   + scraped: The Girl on the Train
#   + scraped: The Genius of Birds
#   + scraped: The Emerald Mystery
#   + scraped: The Cookies & Cups Cookbook: 125+ sweet & savory recipes rem
# [page 9] fetching listing: https://books.toscrape.com/catalogue/page-9.html
#   -> found 20 product links on page
#   + scraped: The Bridge to Consciousness: I'm Writing the Bridge Between
#   + scraped: The Artist's Way: A Spiritual Path to Higher Creativity
#   + scraped: The Art of War
#   + scraped: The Argonauts
#   + scraped: The 10% Entrepreneur: Live Your Startup Dream Without Quitti
#   + scraped: Suddenly in Love (Lake Haven #1)
#   + scraped: Something More Than This
#   + scraped: Soft Apocalypse
#   + scraped: So You've Been Publicly Shamed
#   + scraped: Shoe Dog: A Memoir by the Creator of NIKE
#   + scraped: Shobu Samurai, Project Aryoku (#3)
#   + scraped: Secrets and Lace (Fatal Hearts #1)
#   + scraped: Scarlett Epstein Hates It Here
#   + scraped: Romero and Juliet: A Tragic Tale of Love and Zombies
#   + scraped: Redeeming Love
#   + scraped: Poses for Artists Volume 1 - Dynamic and Sitting Poses: An E
#   + scraped: Poems That Make Grown Women Cry
#   + scraped: Nightingale, Sing
#   + scraped: Night Sky with Exit Wounds
#   + scraped: Mrs. Houdini
# [page 10] fetching listing: https://books.toscrape.com/catalogue/page-10.html
#   -> found 20 product links on page
#   + scraped: Modern Romance
#   + scraped: Miss Peregrineâs Home for Peculiar Children (Miss Peregrin
#   + scraped: Louisa: The Extraordinary Life of Mrs. Adams
#   + scraped: Little Red
#   + scraped: Library of Souls (Miss Peregrineâs Peculiar Children #3)
#   + scraped: Large Print Heart of the Pride
#   + scraped: I Had a Nice Time And Other Lies...: How to find love & sh*t
#   + scraped: Hollow City (Miss Peregrineâs Peculiar Children #2)
#   + scraped: Grumbles
#   + scraped: Full Moon over Noahâs Ark: An Odyssey to Mount Ararat and
#   + scraped: Frostbite (Vampire Academy #2)
#   + scraped: Follow You Home
#   + scraped: First Steps for New Christians (Print Edition)
#   + scraped: Finders Keepers (Bill Hodges Trilogy #2)
#   + scraped: Fables, Vol. 1: Legends in Exile (Fables #1)
#   + scraped: Eureka Trivia 6.0
#   + scraped: Drive: The Surprising Truth About What Motivates Us
#   + scraped: Done Rubbed Out (Reightman & Bailey #1)
#   + scraped: Doing It Over (Most Likely To #1)
#   + scraped: Deliciously Ella Every Day: Quick and Easy Recipes for Glute
# [page 11] fetching listing: https://books.toscrape.com/catalogue/page-11.html
#   -> found 20 product links on page
#   + scraped: Dark Notes
#   + scraped: Daring Greatly: How the Courage to Be Vulnerable Transforms
#   + scraped: Close to You
#   + scraped: Chasing Heaven: What Dying Taught Me About Living
#   + scraped: Big Magic: Creative Living Beyond Fear
#   + scraped: Becoming Wise: An Inquiry into the Mystery and Art of Living
#   + scraped: Beauty Restored (Riley Family Legacy Novellas #3)
#   + scraped: Batman: The Long Halloween (Batman)
#   + scraped: Batman: The Dark Knight Returns (Batman)
#   + scraped: Ayumi's Violin
#   + scraped: Anonymous
#   + scraped: Amy Meets the Saints and Sages
#   + scraped: Amid the Chaos
#   + scraped: Amatus
#   + scraped: Agnostic: A Spirited Manifesto
#   + scraped: Zealot: The Life and Times of Jesus of Nazareth
#   + scraped: You (You #1)
#   + scraped: Wonder Woman: Earth One, Volume One (Wonder Woman: Earth One
#   + scraped: Wild Swans
#   + scraped: Why the Right Went Wrong: Conservatism--From Goldwater to th
# [page 12] fetching listing: https://books.toscrape.com/catalogue/page-12.html
#   -> found 20 product links on page
#   + scraped: Whole Lotta Creativity Going On: 60 Fun and Unusual Exercise
#   + scraped: What's It Like in Space?: Stories from Astronauts Who've Bee
#   + scraped: We Are Robin, Vol. 1: The Vigilante Business (We Are Robin #
#   + scraped: Walt Disney's Alice in Wonderland
#   + scraped: V for Vendetta (V for Vendetta Complete)
#   + scraped: Until Friday Night (The Field Party #1)
#   + scraped: Unbroken: A World War II Story of Survival, Resilience, and
#   + scraped: Twenty Yawns
#   + scraped: Through the Woods
#   + scraped: This Is Where It Ends
#   + scraped: The Year of Magical Thinking
#   + scraped: The Wright Brothers
#   + scraped: The White Queen (The Cousins' War #1)
#   + scraped: The Wedding Pact (The O'Malleys #2)
#   + scraped: The Time Keeper
#   + scraped: The Testament of Mary
#   + scraped: The Star-Touched Queen
#   + scraped: The Songs of the Gods
#   + scraped: The Song of Achilles
#   + scraped: The Rosie Project (Don Tillman #1)
# [page 13] fetching listing: https://books.toscrape.com/catalogue/page-13.html
#   -> found 20 product links on page
#   + scraped: The Power of Habit: Why We Do What We Do in Life and Busines
#   + scraped: The Marriage of Opposites
#   + scraped: The Lucifer Effect: Understanding How Good People Turn Evil
#   + scraped: The Long Haul (Diary of a Wimpy Kid #9)
#   + scraped: The Loney
#   + scraped: The Literature Book (Big Ideas Simply Explained)
#   + scraped: The Last Mile (Amos Decker #2)
#   + scraped: The Immortal Life of Henrietta Lacks
#   + scraped: The Hidden Oracle (The Trials of Apollo #1)
#   + scraped: The Help Yourself Cookbook for Kids: 60 Easy Plant-Based Rec
#   + scraped: The Guilty (Will Robie #4)
#   + scraped: The First Hostage (J.B. Collins #2)
#   + scraped: The Dovekeepers
#   + scraped: The Darkest Lie
#   + scraped: The Bane Chronicles (The Bane Chronicles #1-11)
#   + scraped: The Bad-Ass Librarians of Timbuktu: And Their Race to Save t
#   + scraped: The 14th Colony (Cotton Malone #11)
#   + scraped: That Darkness (Gardiner and Renner #1)
#   + scraped: Tastes Like Fear (DI Marnie Rome #3)
#   + scraped: Take Me with You
# [page 14] fetching listing: https://books.toscrape.com/catalogue/page-14.html
#   -> found 20 product links on page
#   + scraped: Swell: A Year of Waves
#   + scraped: Superman Vol. 1: Before Truth (Superman by Gene Luen Yang #1
#   + scraped: Still Life with Bread Crumbs
#   + scraped: Steve Jobs
#   + scraped: Sorting the Beef from the Bull: The Science of Food Fraud Fo
#   + scraped: Someone Like You (The Harrisons #2)
#   + scraped: So Cute It Hurts!!, Vol. 6 (So Cute It Hurts!! #6)
#   + scraped: Shtum
#   + scraped: See America: A Celebration of Our National Parks & Treasured
#   + scraped: salt.
#   + scraped: Robin War
#   + scraped: Red Hood/Arsenal, Vol. 1: Open for Business (Red Hood/Arsena
#   + scraped: Rain Fish
#   + scraped: Quarter Life Poetry: Poems for the Young, Broke and Hangry
#   + scraped: Pet Sematary
#   + scraped: Overload: How to Unplug, Unwind, and Unleash Yourself from t
#   + scraped: Once Was a Time
#   + scraped: Old School (Diary of a Wimpy Kid #10)
#   + scraped: No Dream Is Too High: Life Lessons From a Man Who Walked on
#   + scraped: Naruto (3-in-1 Edition), Vol. 14: Includes Vols. 40, 41 & 42
# [page 15] fetching listing: https://books.toscrape.com/catalogue/page-15.html
#   -> found 20 product links on page
#   + scraped: My Name Is Lucy Barton
#   + scraped: My Mrs. Brown
#   + scraped: My Kind of Crazy
#   + scraped: Mr. Mercedes (Bill Hodges Trilogy #1)
#   + scraped: More Than Music (Chasing the Dream #1)
#   + scraped: Made to Stick: Why Some Ideas Survive and Others Die
#   + scraped: Luis Paints the World
#   + scraped: Luckiest Girl Alive
#   + scraped: Lowriders to the Center of the Earth (Lowriders in Space #2)
#   + scraped: Love Is a Mix Tape (Music #1)
#   + scraped: Looking for Lovely: Collecting the Moments that Matter
#   + scraped: Living Leadership by Insight: A Good Leader Achieves, a Grea
#   + scraped: Let It Out: A Journey Through Journaling
#   + scraped: Lady Midnight (The Dark Artifices #1)
#   + scraped: It's All Easy: Healthy, Delicious Weeknight Meals in under 3
#   + scraped: Island of Dragons (Unwanteds #7)
#   + scraped: I Know What I'm Doing -- and Other Lies I Tell Myself: Dispa
#   + scraped: I Am Pilgrim (Pilgrim #1)
#   + scraped: Hyperbole and a Half: Unfortunate Situations, Flawed Coping
#   + scraped: Hush, Hush (Hush, Hush #1)
# [page 16] fetching listing: https://books.toscrape.com/catalogue/page-16.html
#   -> found 20 product links on page
#   + scraped: Hold Your Breath (Search and Rescue #1)
#   + scraped: Hamilton: The Revolution
#   + scraped: Greek Mythic History
#   + scraped: God: The Most Unpleasant Character in All Fiction
#   + scraped: Glory over Everything: Beyond The Kitchen House
#   + scraped: Feathers: Displays of Brilliant Plumage
#   + scraped: Far & Away: Places on the Brink of Change: Seven Continents,
#   + scraped: Every Last Word
#   + scraped: Eligible (The Austen Project #4)
#   + scraped: El Deafo
#   + scraped: Eight Hundred Grapes
#   + scraped: Eaternity: More than 150 Deliciously Easy Vegan Recipes for
#   + scraped: Eat Fat, Get Thin
#   + scraped: Don't Get Caught
#   + scraped: Doctor Sleep (The Shining #2)
#   + scraped: Demigods & Magicians: Percy and Annabeth Meet the Kanes (Per
#   + scraped: Dear Mr. Knightley
#   + scraped: Daily Fantasy Sports
#   + scraped: Crazy Love: Overwhelmed by a Relentless God
#   + scraped: Cometh the Hour (The Clifton Chronicles #6)
# [page 17] fetching listing: https://books.toscrape.com/catalogue/page-17.html
#   -> found 20 product links on page
#   + scraped: Code Name Verity (Code Name Verity #1)
#   + scraped: Clockwork Angel (The Infernal Devices #1)
#   + scraped: City of Glass (The Mortal Instruments #3)
#   + scraped: City of Fallen Angels (The Mortal Instruments #4)
#   + scraped: City of Bones (The Mortal Instruments #1)
#   + scraped: City of Ashes (The Mortal Instruments #2)
#   + scraped: Cell
#   + scraped: Catching Jordan (Hundred Oaks)
#   + scraped: Carry On, Warrior: Thoughts on Life Unarmed
#   + scraped: Carrie
#   + scraped: Buying In: The Secret Dialogue Between What We Buy and Who W
#   + scraped: Brain on Fire: My Month of Madness
#   + scraped: Batman: Europa
#   + scraped: Barefoot Contessa Back to Basics
#   + scraped: Barefoot Contessa at Home: Everyday Recipes You'll Make Over
#   + scraped: Balloon Animals
#   + scraped: Art Ops Vol. 1
#   + scraped: Aristotle and Dante Discover the Secrets of the Universe (Ar
#   + scraped: Angels Walking (Angels Walking #1)
#   + scraped: Angels & Demons (Robert Langdon #1)
# [page 18] fetching listing: https://books.toscrape.com/catalogue/page-18.html
#   -> found 20 product links on page
#   + scraped: All the Light We Cannot See
#   + scraped: Adulthood Is a Myth: A "Sarah's Scribbles" Collection
#   + scraped: Abstract City
#   + scraped: A Time of Torment (Charlie Parker #14)
#   + scraped: A Study in Scarlet (Sherlock Holmes #1)
#   + scraped: A Series of Catastrophes and Miracles: A True Story of Love,
#   + scraped: A People's History of the United States
#   + scraped: A Man Called Ove
#   + scraped: A Distant Mirror: The Calamitous 14th Century
#   + scraped: A Brush of Wings (Angels Walking #3)
#   + scraped: 1491: New Revelations of the Americas Before Columbus
#   + scraped: The Three Searches, Meaning, and the Story
#   + scraped: Searching for Meaning in Gailana
#   + scraped: Rook
#   + scraped: My Kitchen Year: 136 Recipes That Saved My Life
#   + scraped: 13 Hours: The Inside Account of What Really Happened In Beng
#   + scraped: Will You Won't You Want Me?
#   + scraped: Tipping Point for Planet Earth: How Close Are We to the Edge
#   + scraped: The Star-Touched Queen
#   + scraped: The Silent Sister (Riley MacPherson #1)
# [page 19] fetching listing: https://books.toscrape.com/catalogue/page-19.html
#   -> found 20 product links on page
#   + scraped: The Midnight Watch: A Novel of the Titanic and the Californi
#   + scraped: The Lonely City: Adventures in the Art of Being Alone
#   + scraped: The Gray Rhino: How to Recognize and Act on the Obvious Dang
#   + scraped: The Golden Condom: And Other Essays on Love Lost and Found
#   + scraped: The Epidemic (The Program 0.6)
#   + scraped: The Dinner Party
#   + scraped: The Diary of a Young Girl
#   + scraped: The Children
#   + scraped: Stars Above (The Lunar Chronicles #4.5)
#   + scraped: Snatched: How A Drug Queen Went Undercover for the DEA and W
#   + scraped: Raspberry Pi Electronics Projects for the Evil Genius
#   + scraped: Quench Your Own Thirst: Business Lessons Learned Over a Beer
#   + scraped: Psycho: Sanitarium (Psycho #1.5)
#   + scraped: Poisonous (Max Revere Novels #3)
#   + scraped: One with You (Crossfire #5)
#   + scraped: No Love Allowed (Dodge Cove #1)
#   + scraped: Murder at the 42nd Street Library (Raymond Ambler #1)
#   + scraped: Most Wanted
#   + scraped: Love, Lies and Spies
#   + scraped: How to Speak Golf: An Illustrated Guide to Links Lingo
# [page 20] fetching listing: https://books.toscrape.com/catalogue/page-20.html
#   -> found 20 product links on page
#   + scraped: Hide Away (Eve Duncan #20)
#   + scraped: Furiously Happy: A Funny Book About Horrible Things
#   + scraped: Everyday Italian: 125 Simple and Delicious Recipes
#   + scraped: Equal Is Unfair: America's Misguided Fight Against Income In
#   + scraped: Eleanor & Park
#   + scraped: Dirty (Dive Bar #1)
#   + scraped: Can You Keep a Secret? (Fear Street Relaunch #4)
#   + scraped: Boar Island (Anna Pigeon #19)
#   + scraped: A Paris Apartment
#   + scraped: A la Mode: 120 Recipes in 60 Pairings: Pies, Tarts, Cakes, C
#   + scraped: Troublemaker: Surviving Hollywood and Scientology
#   + scraped: The Widow
#   + scraped: The Sleep Revolution: Transforming Your Life, One Night at a
#   + scraped: The Improbability of Love
#   + scraped: The Art of Startup Fundraising
#   + scraped: Take Me Home Tonight (Rock Star Romance #3)
#   + scraped: Sleeping Giants (Themis Files #1)
#   + scraped: Setting the World on Fire: The Brief, Astonishing Life of St
#   + scraped: Playing with Fire
#   + scraped: Off the Hook (Fishing for Trouble #1)
# [page 21] fetching listing: https://books.toscrape.com/catalogue/page-21.html
#   -> found 20 product links on page
#   + scraped: Mothering Sunday
#   + scraped: Mother, Can You Not?
#   + scraped: M Train
#   + scraped: Lilac Girls
#   + scraped: Lies and Other Acts of Love
#   + scraped: Lab Girl
#   + scraped: Keep Me Posted
#   + scraped: It Didn't Start with You: How Inherited Family Trauma Shapes
#   + scraped: Grey (Fifty Shades #4)
#   + scraped: Exit, Pursued by a Bear
#   + scraped: Daredevils
#   + scraped: Cravings: Recipes for What You Want to Eat
#   + scraped: Born for This: How to Find the Work You Were Meant to Do
#   + scraped: Arena
#   + scraped: Adultery
#   + scraped: A Mother's Reckoning: Living in the Aftermath of Tragedy
#   + scraped: A Gentleman's Position (Society of Gentlemen #3)
#   + scraped: 11/22/63
#   + scraped: 10% Happier: How I Tamed the Voice in My Head, Reduced Stres
#   + scraped: 10-Day Green Smoothie Cleanse: Lose Up to 15 Pounds in 10 Da
# [page 22] fetching listing: https://books.toscrape.com/catalogue/page-22.html
#   -> found 20 product links on page
#   + scraped: Without Shame
#   + scraped: Watchmen
#   + scraped: Unlimited Intuition Now
#   + scraped: Underlying Notes
#   + scraped: The Shack
#   + scraped: The New Brand You: Your New Image Makes the Sale for You
#   + scraped: The Moosewood Cookbook: Recipes from Moosewood Restaurant, I
#   + scraped: The Flowers Lied
#   + scraped: The Fabric of the Cosmos: Space, Time, and the Texture of Re
#   + scraped: The Book of Mormon
#   + scraped: The Art and Science of Low Carbohydrate Living
#   + scraped: The Alien Club
#   + scraped: Suzie Snowflake: One beautiful flake (a self-esteem story)
#   + scraped: Nap-a-Roo
#   + scraped: NaNo What Now? Finding your editing process, revising your N
#   + scraped: Modern Day Fables
#   + scraped: If I Gave You God's Phone Number....: Searching for Spiritua
#   + scraped: Fruits Basket, Vol. 9 (Fruits Basket #9)
#   + scraped: Dress Your Family in Corduroy and Denim
#   + scraped: Don't Forget Steven
# [page 23] fetching listing: https://books.toscrape.com/catalogue/page-23.html
#   -> found 20 product links on page
#   + scraped: Chernobyl 01:23:40: The Incredible True Story of the World's
#   + scraped: Art and Fear: Observations on the Perils (and Rewards) of Ar
#   + scraped: A Shard of Ice (The Black Symphony Saga #1)
#   + scraped: A Hero's Curse (The Unseen Chronicles #1)
#   + scraped: 23 Degrees South: A Tropical Tale of Changing Whether...
#   + scraped: Zero to One: Notes on Startups, or How to Build the Future
#   + scraped: Why Not Me?
#   + scraped: When Breath Becomes Air
#   + scraped: Vagabonding: An Uncommon Guide to the Art of Long-Term World
#   + scraped: The Unlikely Pilgrimage of Harold Fry (Harold Fry #1)
#   + scraped: The New Drawing on the Right Side of the Brain
#   + scraped: The Midnight Assassin: Panic, Scandal, and the Hunt for Amer
#   + scraped: The Martian (The Martian #1)
#   + scraped: The High Mountains of Portugal
#   + scraped: The Grownup
#   + scraped: The E-Myth Revisited: Why Most Small Businesses Don't Work a
#   + scraped: South of Sunshine
#   + scraped: Smarter Faster Better: The Secrets of Being Productive in Li
#   + scraped: Silence in the Dark (Logan Point #4)
#   + scraped: Shadows of the Past (Logan Point #1)
# [page 24] fetching listing: https://books.toscrape.com/catalogue/page-24.html
#   -> found 20 product links on page
#   + scraped: Roller Girl
#   + scraped: Rising Strong
#   + scraped: Proofs of God: Classical Arguments from Tertullian to Barth
#   + scraped: Please Kill Me: The Uncensored Oral History of Punk
#   + scraped: Out of Print: City Lights Spotlight No. 14
#   + scraped: My Life Next Door (My Life Next Door )
#   + scraped: Miller's Valley
#   + scraped: Man's Search for Meaning
#   + scraped: Love That Boy: What Two Presidents, Eight Road Trips, and My
#   + scraped: Living Forward: A Proven Plan to Stop Drifting and Get the L
#   + scraped: Les Fleurs du Mal
#   + scraped: Left Behind (Left Behind #1)
#   + scraped: Kill 'Em and Leave: Searching for James Brown and the Americ
#   + scraped: Kierkegaard: A Christian Missionary to Christians
#   + scraped: John Vassos: Industrial Design for Modern Life
#   + scraped: I'll Give You the Sun
#   + scraped: I Will Find You
#   + scraped: Hystopia: A Novel
#   + scraped: Howl and Other Poems
#   + scraped: History of Beauty
# [page 25] fetching listing: https://books.toscrape.com/catalogue/page-25.html
#   -> found 20 product links on page
#   + scraped: Heaven is for Real: A Little Boy's Astounding Story of His T
#   + scraped: Future Shock (Future Shock #1)
#   + scraped: Ender's Game (The Ender Quintet #1)
#   + scraped: Diary of a Citizen Scientist: Chasing Tiger Beetles and Othe
#   + scraped: Death by Leisure: A Cautionary Tale
#   + scraped: Brilliant Beacons: A History of the American Lighthouse
#   + scraped: Brazen: The Courage to Find the You That's Been Hiding
#   + scraped: Between the World and Me
#   + scraped: Being Mortal: Medicine and What Matters in the End
#   + scraped: A Murder Over a Girl: Justice, Gender, Junior High
#   + scraped: 32 Yolks
#   + scraped: "Most Blessed of the Patriarchs": Thomas Jefferson and the E
#   + scraped: You Are a Badass: How to Stop Doubting Your Greatness and St
#   + scraped: Wildlife of New York: A Five-Borough Coloring Book
#   + scraped: What Happened on Beale Street (Secrets of the South Mysterie
#   + scraped: Unreasonable Hope: Finding Faith in the God Who Brings Purpo
#   + scraped: Under the Tuscan Sun
#   + scraped: Toddlers Are A**holes: It's Not Your Fault
#   + scraped: The Year of Living Biblically: One Man's Humble Quest to Fol
#   + scraped: The Whale
# [page 26] fetching listing: https://books.toscrape.com/catalogue/page-26.html
#   -> found 20 product links on page
#   + scraped: The Story of Art
#   + scraped: The Origin of Species
#   + scraped: The Great Gatsby
#   + scraped: The Good Girl
#   + scraped: The Glass Castle
#   + scraped: The Faith of Christopher Hitchens: The Restless Soul of the
#   + scraped: The Drowning Girls
#   + scraped: The Constant Princess (The Tudor Court #1)
#   + scraped: The Bourne Identity (Jason Bourne #1)
#   + scraped: The Bachelor Girl's Guide to Murder (Herringford and Watts M
#   + scraped: The Art Book
#   + scraped: The 7 Habits of Highly Effective People: Powerful Lessons in
#   + scraped: Team of Rivals: The Political Genius of Abraham Lincoln
#   + scraped: Steal Like an Artist: 10 Things Nobody Told You About Being
#   + scraped: Sit, Stay, Love
#   + scraped: Sister Dear
#   + scraped: Shrunken Treasures: Literary Classics, Short, Sweet, and Sil
#   + scraped: Rich Dad, Poor Dad
#   + scraped: Raymie Nightingale
#   + scraped: Playing from the Heart
# [page 27] fetching listing: https://books.toscrape.com/catalogue/page-27.html
#   -> found 20 product links on page
#   + scraped: Nightstruck: A Novel
#   + scraped: Naturally Lean: 125 Nourishing Gluten-Free, Plant-Based Reci
#   + scraped: Meternity
#   + scraped: Memoirs of a Geisha
#   + scraped: Like Never Before (Walker Family #2)
#   + scraped: Life of Pi
#   + scraped: Leave This Song Behind: Teen Poetry at Its Best
#   + scraped: King's Folly (The Kinsman Chronicles #1)
#   + scraped: John Adams
#   + scraped: How to Cook Everything Vegetarian: Simple Meatless Recipes f
#   + scraped: How to Be a Domestic Goddess: Baking and the Art of Comfort
#   + scraped: Good in Bed (Cannie Shapiro #1)
#   + scraped: Fruits Basket, Vol. 7 (Fruits Basket #7)
#   + scraped: For the Love: Fighting for Grace in a World of Impossible St
#   + scraped: Finding God in the Ruins: How God Redeems Pain
#   + scraped: Every Heart a Doorway (Every Heart A Doorway #1)
#   + scraped: Delivering the Truth (Quaker Midwife Mystery #1)
#   + scraped: Counted With the Stars (Out from Egypt #1)
#   + scraped: Chronicles, Vol. 1
#   + scraped: Blue Like Jazz: Nonreligious Thoughts on Christian Spiritual
# [page 28] fetching listing: https://books.toscrape.com/catalogue/page-28.html
#   -> found 20 product links on page
#   + scraped: Benjamin Franklin: An American Life
#   + scraped: At The Existentialist CafÃ©: Freedom, Being, and apricot coc
#   + scraped: A Summer In Europe
#   + scraped: A Short History of Nearly Everything
#   + scraped: A Gathering of Shadows (Shades of Magic #2)
#   + scraped: The Sound Of Love
#   + scraped: The Rise and Fall of the Third Reich: A History of Nazi Germ
#   + scraped: The Perks of Being a Wallflower
#   + scraped: The Mysterious Affair at Styles (Hercule Poirot #1)
#   + scraped: The Man Who Mistook His Wife for a Hat and Other Clinical Ta
#   + scraped: The Makings of a Fatherless Child
#   + scraped: The Joy of Cooking
#   + scraped: The Invention of Wings
#   + scraped: The Hobbit (Middle-Earth Universe)
#   + scraped: The Great Railway Bazaar
#   + scraped: The Golden Compass (His Dark Materials #1)
#   + scraped: The God Delusion
#   + scraped: The Girl You Left Behind (The Girl You Left Behind #1)
#   + scraped: The Fellowship of the Ring (The Lord of the Rings #1)
#   + scraped: The Collected Poems of W.B. Yeats (The Collected Works of W.
# [page 29] fetching listing: https://books.toscrape.com/catalogue/page-29.html
#   -> found 20 product links on page
#   + scraped: The Barefoot Contessa Cookbook
#   + scraped: Tell the Wolves I'm Home
#   + scraped: Ship Leaves Harbor: Essays on Travel by a Recovering Journey
#   + scraped: Pride and Prejudice
#   + scraped: Musicophilia: Tales of Music and the Brain
#   + scraped: Mere Christianity
#   + scraped: Me Before You (Me Before You #1)
#   + scraped: In the Woods (Dublin Murder Squad #1)
#   + scraped: In Cold Blood
#   + scraped: How to Stop Worrying and Start Living
#   + scraped: Give It Back
#   + scraped: Girl, Interrupted
#   + scraped: Fun Home: A Family Tragicomic
#   + scraped: Fruits Basket, Vol. 6 (Fruits Basket #6)
#   + scraped: Deception Point
#   + scraped: Death Note, Vol. 6: Give-and-Take (Death Note #6)
#   + scraped: Catherine the Great: Portrait of a Woman
#   + scraped: Better Homes and Gardens New Cook Book
#   + scraped: An Unquiet Mind: A Memoir of Moods and Madness
#   + scraped: A Year in Provence (Provence #1)
# [page 30] fetching listing: https://books.toscrape.com/catalogue/page-30.html
#   -> found 20 product links on page
#   + scraped: World Without End (The Pillars of the Earth #2)
#   + scraped: Will Grayson, Will Grayson (Will Grayson, Will Grayson)
#   + scraped: Why Save the Bankers?: And Other Essays on Our Economic and
#   + scraped: Where She Went (If I Stay #2)
#   + scraped: What If?: Serious Scientific Answers to Absurd Hypothetical
#   + scraped: Two Summers
#   + scraped: This Is Your Brain on Music: The Science of a Human Obsessio
#   + scraped: The Secret Garden
#   + scraped: The Raven King (The Raven Cycle #4)
#   + scraped: The Raven Boys (The Raven Cycle #1)
#   + scraped: The Power Greens Cookbook: 140 Delicious Superfood Recipes
#   + scraped: The Metamorphosis
#   + scraped: The Mathews Men: Seven Brothers and the War Against Hitler's
#   + scraped: The Little Paris Bookshop
#   + scraped: The Hiding Place
#   + scraped: The Grand Design
#   + scraped: The Firm
#   + scraped: The Fault in Our Stars
#   + scraped: The False Prince (The Ascendance Trilogy #1)
#   + scraped: The Expatriates
# [page 31] fetching listing: https://books.toscrape.com/catalogue/page-31.html
#   -> found 20 product links on page
#   + scraped: The Dream Thieves (The Raven Cycle #2)
#   + scraped: The Darkest Corners
#   + scraped: The Crossover
#   + scraped: The 5th Wave (The 5th Wave #1)
#   + scraped: Tell the Wind and Fire
#   + scraped: Tell Me Three Things
#   + scraped: Talking to Girls About Duran Duran: One Young Man's Quest fo
#   + scraped: Siddhartha
#   + scraped: Shiver (The Wolves of Mercy Falls #1)
#   + scraped: Remember Me?
#   + scraped: Red Dragon (Hannibal Lecter #1)
#   + scraped: Peak: Secrets from the New Science of Expertise
#   + scraped: My Mother Was Nuts
#   + scraped: Mexican Today: New and Rediscovered Recipes for Contemporary
#   + scraped: Maybe Something Beautiful: How Art Transformed a Neighborhoo
#   + scraped: Lola and the Boy Next Door (Anna and the French Kiss #2)
#   + scraped: Logan Kade (Fallen Crest High #5.5)
#   + scraped: Last One Home (New Beginnings #1)
#   + scraped: Killing Floor (Jack Reacher #1)
#   + scraped: Kill the Boy Band
# [page 32] fetching listing: https://books.toscrape.com/catalogue/page-32.html
#   -> found 20 product links on page
#   + scraped: Isla and the Happily Ever After (Anna and the French Kiss #3
#   + scraped: If I Stay (If I Stay #1)
#   + scraped: I Know Why the Caged Bird Sings (Maya Angelou's Autobiograph
#   + scraped: Harry Potter and the Deathly Hallows (Harry Potter #7)
#   + scraped: Fruits Basket, Vol. 5 (Fruits Basket #5)
#   + scraped: Foundation (Foundation (Publication Order) #1)
#   + scraped: Fool Me Once
#   + scraped: Find Her (Detective D.D. Warren #8)
#   + scraped: Evicted: Poverty and Profit in the American City
#   + scraped: Drama
#   + scraped: Dracula the Un-Dead
#   + scraped: Digital Fortress
#   + scraped: Death Note, Vol. 5: Whiteout (Death Note #5)
#   + scraped: Data, A Love Story: How I Gamed Online Dating to Meet My Mat
#   + scraped: Critique of Pure Reason
#   + scraped: Booked
#   + scraped: Blue Lily, Lily Blue (The Raven Cycle #3)
#   + scraped: Approval Junkie: Adventures in Caring Too Much
#   + scraped: An Abundance of Katherines
#   + scraped: America's War for the Greater Middle East: A Military Histor
# [page 33] fetching listing: https://books.toscrape.com/catalogue/page-33.html
#   -> found 20 product links on page
#   + scraped: Alight (The Generations Trilogy #2)
#   + scraped: A Girl's Guide to Moving On (New Beginnings #2)
#   + scraped: A Game of Thrones (A Song of Ice and Fire #1)
#   + scraped: A Feast for Crows (A Song of Ice and Fire #4)
#   + scraped: A Clash of Kings (A Song of Ice and Fire #2)
#   + scraped: Vogue Colors A to Z: A Fashion Coloring Book
#   + scraped: The Shining (The Shining #1)
#   + scraped: The Pilgrim's Progress
#   + scraped: The Perfect Play (Play by Play #1)
#   + scraped: The Passion of Dolssa
#   + scraped: The Jazz of Physics: The Secret Link Between Music and the S
#   + scraped: The Hunger Games (The Hunger Games #1)
#   + scraped: The Hound of the Baskervilles (Sherlock Holmes #5)
#   + scraped: The Gunning of America: Business and the Making of American
#   + scraped: The Geography of Bliss: One Grump's Search for the Happiest
#   + scraped: The Demonists (Demonist #1)
#   + scraped: The Demon Prince of Momochi House, Vol. 4 (The Demon Prince
#   + scraped: The Bone Hunters (Lexy Vaughan & Steven Macaulay #2)
#   + scraped: The Beast (Black Dagger Brotherhood #14)
#   + scraped: Some Women
# [page 34] fetching listing: https://books.toscrape.com/catalogue/page-34.html
#   -> found 20 product links on page
#   + scraped: Shopaholic Ties the Knot (Shopaholic #3)
#   + scraped: Paper and Fire (The Great Library #2)
#   + scraped: Outlander (Outlander #1)
#   + scraped: Orchestra of Exiles: The Story of Bronislaw Huberman, the Is
#   + scraped: No One Here Gets Out Alive
#   + scraped: Night Shift (Night Shift #1-20)
#   + scraped: Needful Things
#   + scraped: Mockingjay (The Hunger Games #3)
#   + scraped: Misery
#   + scraped: Little Women (Little Women #1)
#   + scraped: It
#   + scraped: Harry Potter and the Sorcerer's Stone (Harry Potter #1)
#   + scraped: Harry Potter and the Prisoner of Azkaban (Harry Potter #3)
#   + scraped: Harry Potter and the Order of the Phoenix (Harry Potter #5)
#   + scraped: Harry Potter and the Half-Blood Prince (Harry Potter #6)
#   + scraped: Harry Potter and the Chamber of Secrets (Harry Potter #2)
#   + scraped: Gone with the Wind
#   + scraped: God Is Not Great: How Religion Poisons Everything
#   + scraped: Girl With a Pearl Earring
#   + scraped: Fruits Basket, Vol. 4 (Fruits Basket #4)
# [page 35] fetching listing: https://books.toscrape.com/catalogue/page-35.html
#   -> found 20 product links on page
#   + scraped: Far From True (Promise Falls Trilogy #2)
#   + scraped: Dark Lover (Black Dagger Brotherhood #1)
#   + scraped: Confessions of a Shopaholic (Shopaholic #1)
#   + scraped: Changing the Game (Play by Play #2)
#   + scraped: Candide
#   + scraped: Can You Keep a Secret?
#   + scraped: Atlas Shrugged
#   + scraped: Animal Farm
#   + scraped: A Walk to Remember
#   + scraped: A New Earth: Awakening to Your Life's Purpose
#   + scraped: A History of God: The 4,000-Year Quest of Judaism, Christian
#   + scraped: 'Salem's Lot
#   + scraped: Zero History (Blue Ant #3)
#   + scraped: Wuthering Heights
#   + scraped: World War Z: An Oral History of the Zombie War
#   + scraped: Wild: From Lost to Found on the Pacific Crest Trail
#   + scraped: Where'd You Go, Bernadette
#   + scraped: When You Are Engulfed in Flames
#   + scraped: We the People: The Modern-Day Figures Who Have Reshaped and
#   + scraped: We Are All Completely Beside Ourselves
# [page 36] fetching listing: https://books.toscrape.com/catalogue/page-36.html
#   -> found 20 product links on page
#   + scraped: Walk the Edge (Thunder Road #2)
#   + scraped: Voyager (Outlander #3)
#   + scraped: Very Good Lives: The Fringe Benefits of Failure and the Impo
#   + scraped: Vegan Vegetarian Omnivore: Dinner for Everyone at the Table
#   + scraped: Unstuffed: Decluttering Your Home, Mind, and Soul
#   + scraped: Under the Banner of Heaven: A Story of Violent Faith
#   + scraped: Two Boys Kissing
#   + scraped: Twilight (Twilight #1)
#   + scraped: Twenties Girl
#   + scraped: Trespassing Across America: One Man's Epic, Never-Done-Befor
#   + scraped: Three-Martini Lunch
#   + scraped: Thinking, Fast and Slow
#   + scraped: The Wild Robot
#   + scraped: The Wicked + The Divine, Vol. 3: Commercial Suicide (The Wic
#   + scraped: The Undomestic Goddess
#   + scraped: The Travelers
#   + scraped: The Tipping Point: How Little Things Can Make a Big Differen
#   + scraped: The Thing About Jellyfish
#   + scraped: The Stand
#   + scraped: The Smitten Kitchen Cookbook
# [page 37] fetching listing: https://books.toscrape.com/catalogue/page-37.html
#   -> found 20 product links on page
#   + scraped: The Silkworm (Cormoran Strike #2)
#   + scraped: The Sandman, Vol. 3: Dream Country (The Sandman (volumes) #3
#   + scraped: The Rose & the Dagger (The Wrath and the Dawn #2)
#   + scraped: The Road to Little Dribbling: Adventures of an American in B
#   + scraped: The Rise of Theodore Roosevelt (Theodore Roosevelt #1)
#   + scraped: The Restaurant at the End of the Universe (Hitchhiker's Guid
#   + scraped: The Rest Is Noise: Listening to the Twentieth Century
#   + scraped: The Red Tent
#   + scraped: The Purpose Driven Life: What on Earth Am I Here for?
#   + scraped: The Purest Hook (Second Circle Tattoos #3)
#   + scraped: The Picture of Dorian Gray
#   + scraped: The Paris Wife
#   + scraped: The Obsession
#   + scraped: The Nightingale
#   + scraped: The New Guy (and Other Senior Year Distractions)
#   + scraped: The Nanny Diaries (Nanny #1)
#   + scraped: The Name of God is Mercy
#   + scraped: The Maze Runner (The Maze Runner #1)
#   + scraped: The Lover's Dictionary
#   + scraped: The Lonely Ones
# [page 38] fetching listing: https://books.toscrape.com/catalogue/page-38.html
#   -> found 20 product links on page
#   + scraped: The Lean Startup: How Today's Entrepreneurs Use Continuous I
#   + scraped: The Last Painting of Sara de Vos
#   + scraped: The Land of 10,000 Madonnas
#   + scraped: The Infinities
#   + scraped: The Husband's Secret
#   + scraped: The Hitchhiker's Guide to the Galaxy (Hitchhiker's Guide to
#   + scraped: The Guns of August
#   + scraped: The Guernsey Literary and Potato Peel Pie Society
#   + scraped: The Goldfinch
#   + scraped: The Giver (The Giver Quartet #1)
#   + scraped: The Girl with All the Gifts
#   + scraped: The Girl Who Played with Fire (Millennium Trilogy #2)
#   + scraped: The Girl Who Kicked the Hornet's Nest (Millennium Trilogy #3
#   + scraped: The Exiled
#   + scraped: The End of Faith: Religion, Terror, and the Future of Reason
#   + scraped: The Elegant Universe: Superstrings, Hidden Dimensions, and t
#   + scraped: The Disappearing Spoon: And Other True Tales of Madness, Lov
#   + scraped: The Devil Wears Prada (The Devil Wears Prada #1)
#   + scraped: The Demon-Haunted World: Science as a Candle in the Dark
#   + scraped: The Day the Crayons Came Home (Crayons)
# [page 39] fetching listing: https://books.toscrape.com/catalogue/page-39.html
#   -> found 20 product links on page
#   + scraped: The Da Vinci Code (Robert Langdon #2)
#   + scraped: The Cuckoo's Calling (Cormoran Strike #1)
#   + scraped: The Complete Stories and Poems (The Works of Edgar Allan Poe
#   + scraped: The Complete Poems
#   + scraped: The Catcher in the Rye
#   + scraped: The Cat in the Hat (Beginner Books B-1)
#   + scraped: The Case for Christ (Cases for Christianity)
#   + scraped: The Book Thief
#   + scraped: The Book of Basketball: The NBA According to The Sports Guy
#   + scraped: The Blind Side: Evolution of a Game
#   + scraped: The Autobiography of Malcolm X
#   + scraped: The Art of Simple Food: Notes, Lessons, and Recipes from a D
#   + scraped: The Art of Fielding
#   + scraped: Surely You're Joking, Mr. Feynman!: Adventures of a Curious
#   + scraped: Stiff: The Curious Lives of Human Cadavers
#   + scraped: Spilled Milk: Based on a True Story
#   + scraped: Something Borrowed (Darcy & Rachel #1)
#   + scraped: Something Blue (Darcy & Rachel #2)
#   + scraped: Soldier (Talon #3)
#   + scraped: Shopaholic & Baby (Shopaholic #5)
# [page 40] fetching listing: https://books.toscrape.com/catalogue/page-40.html
#   -> found 20 product links on page
#   + scraped: Seven Days in the Art World
#   + scraped: Seven Brief Lessons on Physics
#   + scraped: Scarlet (The Lunar Chronicles #2)
#   + scraped: Sarah's Key
#   + scraped: Saga, Volume 3 (Saga (Collected Editions) #3)
#   + scraped: Running with Scissors
#   + scraped: Rogue Lawyer (Rogue Lawyer #1)
#   + scraped: Rise of the Rocket Girls: The Women Who Propelled Us, from M
#   + scraped: Rework
#   + scraped: Reservations for Two
#   + scraped: Red: The True Story of Red Riding Hood
#   + scraped: Ready Player One
#   + scraped: Quiet: The Power of Introverts in a World That Can't Stop Ta
#   + scraped: Prodigy: The Graphic Novel (Legend: The Graphic Novel #2)
#   + scraped: Persepolis: The Story of a Childhood (Persepolis #1-2)
#   + scraped: Packing for Mars: The Curious Science of Life in the Void
#   + scraped: Outliers: The Story of Success
#   + scraped: Original Fake
#   + scraped: Orange Is the New Black
#   + scraped: One for the Money (Stephanie Plum #1)
# [page 41] fetching listing: https://books.toscrape.com/catalogue/page-41.html
#   -> found 20 product links on page
#   + scraped: Notes from a Small Island (Notes From a Small Island #1)
#   + scraped: Night (The Night Trilogy #1)
#   + scraped: Neither Here nor There: Travels in Europe
#   + scraped: Naked
#   + scraped: Morning Star (Red Rising #3)
#   + scraped: Miracles from Heaven: A Little Girl, Her Journey to Heaven,
#   + scraped: Midnight Riot (Peter Grant/ Rivers of London - books #1)
#   + scraped: Me Talk Pretty One Day
#   + scraped: Manuscript Found in Accra
#   + scraped: Lust & Wonder
#   + scraped: Lila (Gilead #3)
#   + scraped: Life, the Universe and Everything (Hitchhiker's Guide to the
#   + scraped: Life Without a Recipe
#   + scraped: Life After Life
#   + scraped: Letter to a Christian Nation
#   + scraped: Let's Pretend This Never Happened: A Mostly True Memoir
#   + scraped: Legend (Legend #1)
#   + scraped: Lean In: Women, Work, and the Will to Lead
#   + scraped: Lamb: The Gospel According to Biff, Christ's Childhood Pal
#   + scraped: Lady Renegades (Rebel Belle #3)
# [page 42] fetching listing: https://books.toscrape.com/catalogue/page-42.html
#   -> found 20 product links on page
#   + scraped: Jurassic Park (Jurassic Park #1)
#   + scraped: It's Never Too Late to Begin Again: Discovering Creativity a
#   + scraped: Is Everyone Hanging Out Without Me? (And Other Concerns)
#   + scraped: Into the Wild
#   + scraped: Inferno (Robert Langdon #4)
#   + scraped: In the Garden of Beasts: Love, Terror, and an American Famil
#   + scraped: If I Run (If I Run #1)
#   + scraped: I've Got Your Number
#   + scraped: I Am Malala: The Girl Who Stood Up for Education and Was Sho
#   + scraped: Hungry Girl Clean & Hungry: Easy All-Natural Recipes for Hea
#   + scraped: House of Lost Worlds: Dinosaurs, Dynasties, and the Story of
#   + scraped: House of Leaves
#   + scraped: Horrible Bear!
#   + scraped: Holidays on Ice
#   + scraped: Heir to the Sky
#   + scraped: Green Eggs and Ham (Beginner Books B-16)
#   + scraped: Grayson, Vol 3: Nemesis (Grayson #3)
#   + scraped: Gratitude
#   + scraped: Gone Girl
#   + scraped: Golden (Heart of Dread #3)
# [page 43] fetching listing: https://books.toscrape.com/catalogue/page-43.html
#   -> found 20 product links on page
#   + scraped: Girl in the Blue Coat
#   + scraped: Fruits Basket, Vol. 3 (Fruits Basket #3)
#   + scraped: Friday Night Lights: A Town, a Team, and a Dream
#   + scraped: Fire Bound (Sea Haven/Sisters of the Heart #5)
#   + scraped: Fifty Shades Freed (Fifty Shades #3)
#   + scraped: Fellside
#   + scraped: Extreme Prey (Lucas Davenport #26)
#   + scraped: Eragon (The Inheritance Cycle #1)
#   + scraped: Eclipse (Twilight #3)
#   + scraped: Dune (Dune #1)
#   + scraped: Dracula
#   + scraped: Do Androids Dream of Electric Sheep? (Blade Runner #1)
#   + scraped: Disrupted: My Misadventure in the Start-Up Bubble
#   + scraped: Dead Wake: The Last Crossing of the Lusitania
#   + scraped: David and Goliath: Underdogs, Misfits, and the Art of Battli
#   + scraped: Darkfever (Fever #1)
#   + scraped: Dark Places
#   + scraped: Crazy Rich Asians (Crazy Rich Asians #1)
#   + scraped: Counting Thyme
#   + scraped: Cosmos
# [page 44] fetching listing: https://books.toscrape.com/catalogue/page-44.html
#   -> found 20 product links on page
#   + scraped: Civilization and Its Discontents
#   + scraped: Cinder (The Lunar Chronicles #1)
#   + scraped: Catastrophic Happiness: Finding Joy in Childhood's Messy Yea
#   + scraped: Career of Evil (Cormoran Strike #3)
#   + scraped: Breaking Dawn (Twilight #4)
#   + scraped: Brave Enough
#   + scraped: Boy Meets Boy
#   + scraped: Born to Run: A Hidden Tribe, Superathletes, and the Greatest
#   + scraped: Blink: The Power of Thinking Without Thinking
#   + scraped: Black Flags: The Rise of ISIS
#   + scraped: Black Butler, Vol. 1 (Black Butler #1)
#   + scraped: Big Little Lies
#   + scraped: Between Shades of Gray
#   + scraped: Best of My Love (Fool's Gold #20)
#   + scraped: Beowulf
#   + scraped: Beautiful Creatures (Caster Chronicles #1)
#   + scraped: Awkward
#   + scraped: Ash
#   + scraped: Are We There Yet?
#   + scraped: Are We Smart Enough to Know How Smart Animals Are?
# [page 45] fetching listing: https://books.toscrape.com/catalogue/page-45.html
#   -> found 20 product links on page
#   + scraped: Annie on My Mind
#   + scraped: And Then There Were None
#   + scraped: A Walk in the Woods: Rediscovering America on the Appalachia
#   + scraped: A Visit from the Goon Squad
#   + scraped: A Storm of Swords (A Song of Ice and Fire #3)
#   + scraped: A Heartbreaking Work of Staggering Genius
#   + scraped: 8 Keys to Mental Health Through Exercise
#   + scraped: #GIRLBOSS
#   + scraped: The Suffragettes (Little Black Classics, #96)
#   + scraped: The Sense of an Ending
#   + scraped: The Sandman, Vol. 2: The Doll's House (The Sandman (volumes)
#   + scraped: The Course of Love
#   + scraped: Sugar Rush (Offensive Line #2)
#   + scraped: Saga, Volume 2 (Saga (Collected Editions) #2)
#   + scraped: Run, Spot, Run: The Ethics of Keeping Pets
#   + scraped: New Moon (Twilight #2)
#   + scraped: Life
#   + scraped: Kindle Paperwhite User's Guide
#   + scraped: H is for Hawk
#   + scraped: Girl Online On Tour (Girl Online #2)
# [page 46] fetching listing: https://books.toscrape.com/catalogue/page-46.html
#   -> found 20 product links on page
#   + scraped: Fruits Basket, Vol. 2 (Fruits Basket #2)
#   + scraped: Diary of a Minecraft Zombie Book 1: A Scare of a Dare (An Un
#   + scraped: Y: The Last Man, Vol. 1: Unmanned (Y: The Last Man #1)
#   + scraped: While You Were Mine
#   + scraped: Where Lightning Strikes (Bleeding Stars #3)
#   + scraped: When I'm Gone
#   + scraped: Ways of Seeing
#   + scraped: Vampire Knight, Vol. 1 (Vampire Knight #1)
#   + scraped: Vampire Girl (Vampire Girl #1)
#   + scraped: Twenty Love Poems and a Song of Despair
#   + scraped: Travels with Charley: In Search of America
#   + scraped: Three Wishes (River of Time: California #1)
#   + scraped: This One Moment (Pushing Limits #1)
#   + scraped: The Zombie Room
#   + scraped: The Wicked + The Divine, Vol. 1: The Faust Act (The Wicked +
#   + scraped: The Tumor
#   + scraped: The Story of Hong Gildong
#   + scraped: The Silent Wife
#   + scraped: The Silent Twin (Detective Jennifer Knight #3)
#   + scraped: The Selfish Gene
# [page 47] fetching listing: https://books.toscrape.com/catalogue/page-47.html
#   -> found 20 product links on page
#   + scraped: The Secret Healer
#   + scraped: The Sandman, Vol. 1: Preludes and Nocturnes (The Sandman (vo
#   + scraped: The Republic
#   + scraped: The Odyssey
#   + scraped: The No. 1 Ladies' Detective Agency (No. 1 Ladies' Detective
#   + scraped: The Nicomachean Ethics
#   + scraped: The Name of the Wind (The Kingkiller Chronicle #1)
#   + scraped: The Mirror & the Maze (The Wrath and the Dawn #1.5)
#   + scraped: The Little Prince
#   + scraped: The Light of the Fireflies
#   + scraped: The Last Girl (The Dominion Trilogy #1)
#   + scraped: The Iliad
#   + scraped: The Hook Up (Game On #1)
#   + scraped: The Haters
#   + scraped: The Girl You Lost
#   + scraped: The Girl In The Ice (DCI Erika Foster #1)
#   + scraped: The End of the Jesus Era (An Investigation #1)
#   + scraped: The Edge of Reason (Bridget Jones #2)
#   + scraped: The Complete Maus (Maus #1-2)
#   + scraped: The Communist Manifesto
# [page 48] fetching listing: https://books.toscrape.com/catalogue/page-48.html
#   -> found 20 product links on page
#   + scraped: The Bhagavad Gita
#   + scraped: The Bette Davis Club
#   + scraped: The Art of Not Breathing
#   + scraped: Taking Shots (Assassins #1)
#   + scraped: Starlark
#   + scraped: Skip Beat!, Vol. 01 (Skip Beat! #1)
#   + scraped: Sister Sable (The Mad Queen #1)
#   + scraped: Shatter Me (Shatter Me #1)
#   + scraped: Shameless
#   + scraped: Shadow Rites (Jane Yellowrock #10)
#   + scraped: Settling the Score (The Summer Games #1)
#   + scraped: Sense and Sensibility
#   + scraped: Saga, Volume 1 (Saga (Collected Editions) #1)
#   + scraped: Rhythm, Chord & Malykhin
#   + scraped: Rat Queens, Vol. 1: Sass & Sorcery (Rat Queens (Collected Ed
#   + scraped: Paradise Lost (Paradise #1)
#   + scraped: Paper Girls, Vol. 1 (Paper Girls #1-5)
#   + scraped: Ouran High School Host Club, Vol. 1 (Ouran High School Host
#   + scraped: Origins (Alphas 0.5)
#   + scraped: One Second (Seven #7)
# [page 49] fetching listing: https://books.toscrape.com/catalogue/page-49.html
#   -> found 20 product links on page
#   + scraped: On the Road (Duluoz Legend)
#   + scraped: Old Records Never Die: One Man's Quest for His Vinyl and His
#   + scraped: Off Sides (Off #1)
#   + scraped: Of Mice and Men
#   + scraped: Myriad (Prentor #1)
#   + scraped: My Perfect Mistake (Over the Top #1)
#   + scraped: Ms. Marvel, Vol. 1: No Normal (Ms. Marvel (2014-2015) #1)
#   + scraped: Meditations
#   + scraped: Matilda
#   + scraped: Lost Among the Living
#   + scraped: Lord of the Flies
#   + scraped: Listen to Me (Fusion #1)
#   + scraped: Kitchens of the Great Midwest
#   + scraped: Jane Eyre
#   + scraped: Imperfect Harmony
#   + scraped: Icing (Aces Hockey #2)
#   + scraped: Hawkeye, Vol. 1: My Life as a Weapon (Hawkeye #1)
#   + scraped: Having the Barbarian's Baby (Ice Planet Barbarians #7.5)
#   + scraped: Giant Days, Vol. 1 (Giant Days #1-4)
#   + scraped: Fruits Basket, Vol. 1 (Fruits Basket #1)
# [page 50] fetching listing: https://books.toscrape.com/catalogue/page-50.html
#   -> found 20 product links on page
#   + scraped: Frankenstein
#   + scraped: Forever Rockers (The Rocker #12)
#   + scraped: Fighting Fate (Fighting #6)
#   + scraped: Emma
#   + scraped: Eat, Pray, Love
#   + scraped: Deep Under (Walker Security #1)
#   + scraped: Choosing Our Religion: The Spiritual Lives of America's None
#   + scraped: Charlie and the Chocolate Factory (Charlie Bucket #1)
#   + scraped: Charity's Cross (Charles Towne Belles #4)
#   + scraped: Bright Lines
#   + scraped: Bridget Jones's Diary (Bridget Jones #1)
#   + scraped: Bounty (Colorado Mountain #7)
#   + scraped: Blood Defense (Samantha Brinkman #1)
#   + scraped: Bleach, Vol. 1: Strawberry and the Soul Reapers (Bleach #1)
#   + scraped: Beyond Good and Evil
#   + scraped: Alice in Wonderland (Alice's Adventures in Wonderland #1)
#   + scraped: Ajin: Demi-Human, Volume 1 (Ajin: Demi-Human #1)
#   + scraped: A Spy's Devotion (The Regency Spies of London #1)
#   + scraped: 1st to Die (Women's Murder Club #1)
#   + scraped: 1,000 Places to See Before You Die
# Scraped 1000 books. Saving to CSV...
# Saved to books.csv (and books.parquet if pyarrow installed).
# Columns: ['category', 'code', 'cover', 'title', 'rating', 'price (excl. tax)', 'price (incl. tax)', 'tax', 'stock status', 'number of stock available', 'description', 'number of reviews', 'product_page_url']
# [{'category': 'Poetry', 'code': 'a897fe39b1053632', 'cover': 'https://books.toscrape.com/media/cache/fe/72/fe72f0532301ec28892ae79a629a293c.jpg', 'title': 'A Light in the Attic', 'rating': 3, 'price (excl. tax)': 'Â£51.77', 'price (incl. tax)': 'Â£51.77', 'tax': 'Â£0.00', 'stock status': 'In stock (22 available)', 'number of stock available': 22, 'description': "It's hard to imagine a world without A Light in the Attic. This now-classic collection of poetry and drawings from Shel Silverstein celebrates its 20th anniversary with this special edition. Silverstein's humorous and creative verse can amuse the dowdiest of readers. Lemon-faced adults and fidgety kids sit still and read these rhythmic words and laugh and smile and love th It's hard to imagine a world without A Light in the Attic. This now-classic collection of poetry and drawings from Shel Silverstein celebrates its 20th anniversary with this special edition. Silverstein's humorous and creative verse can amuse the dowdiest of readers. Lemon-faced adults and fidgety kids sit still and read these rhythmic words and laugh and smile and love that Silverstein. Need proof of his genius? RockabyeRockabye baby, in the treetopDon't you know a treetopIs no safe place to rock?And who put you up there,And your cradle, too?Baby, I think someone down here'sGot it in for you. Shel, you never sounded so good. ...more", 'number of reviews': 0, 'product_page_url': 'https://books.toscrape.com/catalogue/a-light-in-the-attic_1000/index.html'}, {'category': 'Historical Fiction', 'code': '90fa61229261140a', 'cover': 'https://books.toscrape.com/media/cache/08/e9/08e94f3731d7d6b760dfbfbc02ca5c62.jpg', 'title': 'Tipping the Velvet', 'rating': 1, 'price (excl. tax)': 'Â£53.74', 'price (incl. tax)': 'Â£53.74', 'tax': 'Â£0.00', 'stock status': 'In stock (20 available)', 'number of stock available': 20, 'description': '"Erotic and absorbing...Written with starling power."--"The New York Times Book Review " Nan King, an oyster girl, is captivated by the music hall phenomenon Kitty Butler, a male impersonator extraordinaire treading the boards in Canterbury. Through a friend at the box office, Nan manages to visit all her shows and finally meet her heroine. Soon after, she becomes Kitty\'s "Erotic and absorbing...Written with starling power."--"The New York Times Book Review " Nan King, an oyster girl, is captivated by the music hall phenomenon Kitty Butler, a male impersonator extraordinaire treading the boards in Canterbury. Through a friend at the box office, Nan manages to visit all her shows and finally meet her heroine. Soon after, she becomes Kitty\'s dresser and the two head for the bright lights of Leicester Square where they begin a glittering career as music-hall stars in an all-singing and dancing double act. At the same time, behind closed doors, they admit their attraction to each other and their affair begins. ...more', 'number of reviews': 0, 'product_page_url': 'https://books.toscrape.com/catalogue/tipping-the-velvet_999/index.html'}, {'category': 'Fiction', 'code': '6957f44c3847a760', 'cover': 'https://books.toscrape.com/media/cache/ee/cf/eecfe998905e455df12064dba399c075.jpg', 'title': 'Soumission', 'rating': 1, 'price (excl. tax)': 'Â£50.10', 'price (incl. tax)': 'Â£50.10', 'tax': 'Â£0.00', 'stock status': 'In stock (20 available)', 'number of stock available': 20, 'description': 'Dans une France assez proche de la nÃ´tre, un homme sâ\x80\x99engage dans la carriÃ¨re universitaire. Peu motivÃ© par lâ\x80\x99enseignement, il sâ\x80\x99attend Ã\xa0 une vie ennuyeuse mais calme, protÃ©gÃ©e des grands drames historiques. Cependant les forces en jeu dans le pays ont fissurÃ© le systÃ¨me politique jusquâ\x80\x99Ã\xa0 provoquer son effondrement. Cette implosion sans soubresauts, sans vraie rÃ©volution, s Dans une France assez proche de la nÃ´tre, un homme sâ\x80\x99engage dans la carriÃ¨re universitaire. Peu motivÃ© par lâ\x80\x99enseignement, il sâ\x80\x99attend Ã\xa0 une vie ennuyeuse m ...

# %%
df = pd.read_csv('/content/books.csv')
print(df.head())
# Out:
#              category              code  \
# 0              Poetry  a897fe39b1053632
# 1  Historical Fiction  90fa61229261140a
# 2             Fiction  6957f44c3847a760
# 3             Mystery  e00eb4fd7b871a48
# 4             History  4165285e1663650f
#
#                                                cover  \
# 0  https://books.toscrape.com/media/cache/fe/72/f...
# 1  https://books.toscrape.com/media/cache/08/e9/0...
# 2  https://books.toscrape.com/media/cache/ee/cf/e...
# 3  https://books.toscrape.com/media/cache/c0/59/c...
# 4  https://books.toscrape.com/media/cache/ce/5f/c...
#
#                                    title  rating price (excl. tax)  \
# 0                   A Light in the Attic       3           Â£51.77
# 1                     Tipping the Velvet       1           Â£53.74
# 2                             Soumission       1           Â£50.10
# 3                          Sharp Objects       4           Â£47.82
# 4  Sapiens: A Brief History of Humankind       5           Â£54.23
#
#   price (incl. tax)     tax             stock status  \
# 0           Â£51.77  Â£0.00  In stock (22 available)
# 1           Â£53.74  Â£0.00  In stock (20 available)
# 2           Â£50.10  Â£0.00  In stock (20 available)
# 3           Â£47.82  Â£0.00  In stock (20 available)
# 4           Â£54.23  Â£0.00  In stock (20 available)
#
#    number of stock available  \
# 0                         22
# 1                         20
# 2                         20
# 3                         20
# 4                         20
#
#                                          description  number of reviews  \
# 0  It's hard to imagine a world without A Light i...                  0
# 1  "Erotic and absorbing...Written with starling ...                  0
# 2  Dans une France assez proche de la nÃ´tre, un ...                  0
# 3  WICKED above her hipbone, GIRL across her hear...                  0
# 4  From a renowned historian comes a groundbreaki...                  0
#
#                                     product_page_url
# 0  https://books.toscrape.com/catalogue/a-light-i...
# 1  https://books.toscrape.com/catalogue/tipping-t...
# 2  https://books.toscrape.com/catalogue/soumissio...
# 3  https://books.toscrape.com/catalogue/sharp-obj...
# 4  https://books.toscrape.com/catalogue/sapiens-a...
